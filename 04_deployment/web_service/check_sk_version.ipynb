# %%
import joblib

model = joblib.load("lin_reg.bin")

print(model.__module__)
print(model.__class__)
# Out:
# sklearn.linear_model._base
# <class 'sklearn.linear_model._base.LinearRegression'>

# %%
print(model.__getstate__())
# Out:
# {'fit_intercept': True, 'copy_X': True, 'n_jobs': None, 'positive': False, 'n_features_in_': 515, 'coef_': array([ 1.83417772e+01, -2.49233732e+01, -4.55545826e+00, -3.59729458e+00,
#        -1.54169672e+00,  7.61541389e+00, -6.24523433e+00,  6.42700778e+00,
#         1.52003349e+01,  7.12659253e+00,  9.60349905e+00,  4.37684494e-01,
#        -4.83405976e+00, -4.16126584e+00,  5.96903491e+00,  1.54989053e+00,
#         3.40633617e+00,  9.11716069e+00,  1.12263056e+00,  8.67983407e-01,
#         2.61349231e+00, -7.71015849e+00, -5.00757123e+00,  3.78189242e+00,
#        -1.90897406e+01, -3.59558939e+00,  1.73285912e+00,  4.19017711e+00,
#         5.65894688e+00, -1.01017487e+00, -1.43327606e-01, -1.59114389e+01,
#        -7.97839767e+00,  1.50684011e+01,  7.74865763e+00, -1.00140176e+01,
#        -9.90393770e+00,  6.73789521e+00, -6.33742838e+00,  7.12841393e+00,
#        -1.79983648e+01,  8.04127577e+00, -4.33698753e+00, -5.96647600e+00,
# ...
