# %% [markdown]
# # Hyperopt and MLFlow implementation

# %% [markdown]
# ## 1. Simple MLFlow implementation

# %%
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import root_mean_squared_error

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# 2025/05/08 11:33:53 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/Users/gabi/codes/ml_ops/02_experiment_tracking/mlflow-examples/mlruns/2', creation_time=1746696833594, experiment_id='2', last_update_time=1746696833594, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
# read the data and treat it
# change compression if needed

def read_dataframe(filename, compression='gzip'):
    df = pd.read_csv(filename, compression=compression)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)

    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.csv.gz')
df_val = read_dataframe('./data/green_tripdata_2021-02.csv.gz')
# Out:
# /var/folders/55/x1yqz6851xj6j2f0smdhs4jh0000gn/T/ipykernel_39063/697616853.py:5: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, compression=compression)

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
# We will use feature engineering to create a new feature called PU_DO 
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
# set the features we will use
categorical = ['PU_DO'] 
numerical = ['trip_distance']

# We will use the DictVectorizer to convert categorical variables into a format that can be used by the model
dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
# set the target variable

target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
# We will use the LinearRegression model to train the data
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

root_mean_squared_error(y_val, y_pred)
# Out:
# 7.758715210533294

# %%
# save the model
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
# save the model with mlflow
with mlflow.start_run():

    mlflow.set_tag("developer", "gabi")

    mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %% [markdown]
# ## 2.0 Using xgb and Hyperopt

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
# first we need to define the objective function
def objective(params):
    # the parameters are passed both to mlflow and to xgboost
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)

        # configure the parameters of the model
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )

        # once the model is trained, we can save it and make predictions
        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)

        mlflow.log_metric("rmse", rmse)
        
    # we return the loss, which is the value we want to minimize
    # and the status of the optimization
    return {'loss': rmse, 'status': STATUS_OK}

# %%
# define the search space

# note: when we use hp.loguniform, we are exploring the range exponention(low value, high value)

search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),  # here we need to convert to int, as this value only takes int
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

# we can use the fmin function to minimize the objective function
best_result = fmin(
    fn=objective, # the function we defined above
    space=search_space, # the search space we defined above
    algo=tpe.suggest, # the algorithm we will use to search the space
    max_evals=50,
    trials=Trials()
)
# Out:
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# /usr/local/anaconda3/lib/python3.12/site-packages/xgboost/callback.py:386: UserWarning: [11:53:32] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation-rmse:11.67987
# [1]	validation-rmse:11.19362
# [2]	validation-rmse:10.74946
# [3]	validation-rmse:10.34531
# [4]	validation-rmse:9.97723
# [5]	validation-rmse:9.64195
# [6]	validation-rmse:9.34106
# [7]	validation-rmse:9.06745
# [8]	validation-rmse:8.81763
# [9]	validation-rmse:8.59417
# [10]	validation-rmse:8.39069
# [11]	validation-rmse:8.20894
# [12]	validation-rmse:8.04273
# [13]	validation-rmse:7.89479
# [14]	validation-rmse:7.76631
# [15]	validation-rmse:7.64668
# [16]	validation-rmse:7.53888
# [17]	validation-rmse:7.44458
# [18]	validation-rmse:7.35664
# [19]	validation-rmse:7.28112
# [20]	validation-rmse:7.21172
# [21]	validation-rmse:7.14977
# [22]	validation-rmse:7.09479
# [23]	validation-rmse:7.04375
# [24]	validation-rmse:6.99860
# [25]	validation-rmse:6.95649
# [26]	validation-rmse:6.92184
# [27]	validation-rmse:6.88843
# [28]	validation-rmse:6.85959
# [29]	validation-rmse:6.83409
# [30]	validation-rmse:6.80894
# [31]	validation-rmse:6.78556
# [32]	validation-rmse:6.76617
# [33]	validation-rmse:6.74597
# [34]	validation-rmse:6.72954
# [35]	validation-rmse:6.71477
# [36]	validation-rmse:6.70105
# [37]	validation-rmse:6.68938
# [38]	validation-rmse:6.67573
# [39]	validation-rmse:6.66498
# [40]	validation-rmse:6.65645
# [41]	validation-rmse:6.64732
# [42]	validation-rmse:6.63909
# [43]	validation-rmse:6.63073
# [44]	validation-rmse:6.62124
# [45]	validation-rmse:6.61466
# [46]	validation-rmse:6.60729
# [47]	validation-rmse:6.60268
# [48]	validation-rmse:6.59759
# [49]	validation-rmse:6.59264
# [50]	validation-rmse:6.58817
# [51]	validation-rmse:6.58467
# [52]	validation-rmse:6.58065
# [53]	validation-rmse:6.57732
# [54]	validation-rmse:6.57398
# [55]	validation-rmse:6.57082
# [56]	validation-rmse:6.56834
# [57]	validation-rmse:6.56598
# [58]	validation-rmse:6.56260
# [59]	validation-rmse:6.56026
# [60]	validation-rmse:6.55814
# [61]	validation-rmse:6.55631
# [62]	validation-rmse:6.55375
# [63]	validation-rmse:6.55181
# [64]	validation-rmse:6.55039
# [65]	validation-rmse:6.54865
# [66]	validation-rmse:6.54706
# [67]	validation-rmse:6.54534
# [68]	validation-rmse:6.54413
# [69]	validation-rmse:6.54217
# [70]	validation-rmse:6.54040
# [71]	validation-rmse:6.53924
# [72]	validation-rmse:6.53812
# [73]	validation-rmse:6.53665
# [74]	validation-rmse:6.53528
# [75]	validation-rmse:6.53389
# [76]	validation-rmse:6.53293
# [77]	validation-rmse:6.53250
# [78]	validation-rmse:6.53104
# [79]	validation-rmse:6.53033
# [80]	validation-rmse:6.52940
# [81]	validation-rmse:6.52856
# [82]	validation-rmse:6.52771
# [83]	validation-rmse:6.52674
# [84]	validation-rmse:6.52587
# [85]	validation-rmse:6.52546
# [86]	validation-rmse:6.52491
# [87]	validation-rmse:6.52399
# [88]	validation-rmse:6.52329
# [89]	validation-rmse:6.52213
# [90]	validation-rmse:6.52137
# [91]	validation-rmse:6.52049
# [92]	validation-rmse:6.51980
# [93]	validation-rmse:6.51904
# [94]	validation-rmse:6.51853
# [95]	validation-rmse:6.51783
# [96]	validation-rmse:6.51701
# [97]	validation-rmse:6.51638
# [98]	validation-rmse:6.51566
# [99]	validation-rmse:6.51527
# [100]	validation-rmse:6.51485
# [101]	validation-rmse:6.51445
# [102]	validation-rmse:6.51376
# [103]	validation-rmse:6.51342
# [104]	validation-rmse:6.51298
# [105]	validation-rmse:6.51242
# [106]	validation-rmse:6.51136
# [107]	validation-rmse:6.51080
# [108]	validation-rmse:6.51005
# [109]	validation-rmse:6.50926
# [110]	validation-rmse:6.50845
# [111]	validation-rmse:6.50798
# [112]	validation-rmse:6.50761
# [113]	validation-rmse:6.50698
# [114]	validation-rmse:6.50652
# [115]	validation-rmse:6.50604
# [116]	validation-rmse:6.50539
# [117]	validation-rmse:6.50498
# [118]	validation-rmse:6.50458
# [119]	validation-rmse:6.50413
# [120]	validation-rmse:6.50375
# [121]	validation-rmse:6.50341
# [122]	validation-rmse:6.50308
# [123]	validation-rmse:6.50278
# [124]	validation-rmse:6.50239
# [125]	validation-rmse:6.50195
# [126]	validation-rmse:6.50152
# [127]	validation-rmse:6.50114
# [128]	validation-rmse:6.50085
# [129]	validation-rmse:6.50022
# [130]	validation-rmse:6.49965
# [131]	validation-rmse:6.49917
# [132]	validation-rmse:6.49869
# [133]	validation-rmse:6.49835
# [134]	validation-rmse:6.49768
# [135]	validation-rmse:6.49737
# [136]	validation-rmse:6.49695
# [137]	validation-rmse:6.49655
# [138]	validation-rmse:6.49639
# [139]	validation-rmse:6.49605
# [140]	validation-rmse:6.49582
# [141]	validation-rmse:6.49513
# [142]	validation-rmse:6.49473
# [143]	validation-rmse:6.49446
# [144]	validation-rmse:6.49406
# [145]	validation-rmse:6.49360
# [146]	validation-rmse:6.49324
# [147]	validation-rmse:6.49284
# [148]	validation-rmse:6.49266
# [149]	validation-rmse:6.49247
# [150]	validation-rmse:6.49213
# [151]	validation-rmse:6.49180
# [152]	validation-rmse:6.49148
# [153]	validation-rmse:6.49111
# [154]	validation-rmse:6.49100
# [155]	validation-rmse:6.49076
# [156]	validation-rmse:6.49015
# [157]	validation-rmse:6.48964
# [158]	validation-rmse:6.48921
# [159]	validation-rmse:6.48890
# [160]	validation-rmse:6.48875
# [161]	validation-rmse:6.48826
# [162]	validation-rmse:6.48788
# [163]	validation-rmse:6.48753
# [164]	validation-rmse:6.48711
# [165]	validation-rmse:6.48657
# [166]	validation-rmse:6.48610
# [167]	validation-rmse:6.48584
# [168]	validation-rmse:6.48565
# [169]	validation-rmse:6.48519
# [170]	validation-rmse:6.48488
# [171]	validation-rmse:6.48474
# [172]	validation-rmse:6.48456
# [173]	validation-rmse:6.48431
# [174]	validation-rmse:6.48388
# [175]	validation-rmse:6.48341
# [176]	validation-rmse:6.48299
# [177]	validation-rmse:6.48268
# [178]	validation-rmse:6.48216
# [179]	validation-rmse:6.48192
# [180]	validation-rmse:6.48183
# [181]	validation-rmse:6.48156
# [182]	validation-rmse:6.48131
# [183]	validation-rmse:6.48062
# [184]	validation-rmse:6.48028
# [185]	validation-rmse:6.47985
# [186]	validation-rmse:6.47971
# [187]	validation-rmse:6.47958
# [188]	validation-rmse:6.47929
# [189]	validation-rmse:6.47920
# [190]	validation-rmse:6.47892
# [191]	validation-rmse:6.47869
# [192]	validation-rmse:6.47831
# [193]	validation-rmse:6.47803
# [194]	validation-rmse:6.47761
# [195]	validation-rmse:6.47729
# [196]	validation-rmse:6.47703
# [197]	validation-rmse:6.47677
# [198]	validation-rmse:6.47654
# [199]	validation-rmse:6.47622
# [200]	validation-rmse:6.47588
# [201]	validation-rmse:6.47584
# [202]	validation-rmse:6.47562
# [203]	validation-rmse:6.47514
# [204]	validation-rmse:6.47447
# [205]	validation-rmse:6.47419
# [206]	validation-rmse:6.47415
# [207]	validation-rmse:6.47365
# [208]	validation-rmse:6.47333
# [209]	validation-rmse:6.47303
# [210]	validation-rmse:6.47273
# [211]	validation-rmse:6.47240
# [212]	validation-rmse:6.47200
# [213]	validation-rmse:6.47177
# [214]	validation-rmse:6.47148
# [215]	validation-rmse:6.47143
# [216]	validation-rmse:6.47103
# [217]	validation-rmse:6.47081
# [218]	validation-rmse:6.47070
# [219]	validation-rmse:6.47042
# [220]	validation-rmse:6.47016
# [221]	validation-rmse:6.46985
# [222]	validation-rmse:6.46960
# [223]	validation-rmse:6.46938
# [224]	validation-rmse:6.46890
# [225]	validation-rmse:6.46880
# [226]	validation-rmse:6.46851
# [227]	validation-rmse:6.46821
# [228]	validation-rmse:6.46790
# [229]	validation-rmse:6.46784
# [230]	validation-rmse:6.46779
# [231]	validation-rmse:6.46718
# [232]	validation-rmse:6.46696
# [233]	validation-rmse:6.46672
# [234]	validation-rmse:6.46663
# [235]	validation-rmse:6.46651
# [236]	validation-rmse:6.46628
# [237]	validation-rmse:6.46601
# [238]	validation-rmse:6.46568
# [239]	validation-rmse:6.46531
# [240]	validation-rmse:6.46507
# [241]	validation-rmse:6.46499
# [242]	validation-rmse:6.46506
# [243]	validation-rmse:6.46489
# [244]	validation-rmse:6.46453
# [245]	validation-rmse:6.46451
# [246]	validation-rmse:6.46388
# [247]	validation-rmse:6.46365
# [248]	validation-rmse:6.46343
# [249]	validation-rmse:6.46311
# [250]	validation-rmse:6.46293
# [251]	validation-rmse:6.46281
# [252]	validation-rmse:6.46259
# [253]	validation-rmse:6.46228
# [254]	validation-rmse:6.46216
# [255]	validation-rmse:6.46187
# [256]	validation-rmse:6.46162
# [257]	validation-rmse:6.46145
# [258]	validation-rmse:6.46094
# [259]	validation-rmse:6.46068
# [260]	validation-rmse:6.46039
# [261]	validation-rmse:6.46031
# [262]	validation-rmse:6.46013
# [263]	validation-rmse:6.46005
# [264]	validation-rmse:6.45970
# [265]	validation-rmse:6.45932
# [266]	validation-rmse:6.45921
# [267]	validation-rmse:6.45896
# [268]	validation-rmse:6.45857
# [269]	validation-rmse:6.45837
# [270]	validation-rmse:6.45812
# [271]	validation-rmse:6.45751
# [272]	validation-rmse:6.45731
# [273]	validation-rmse:6.45717
# [274]	validation-rmse:6.45695
# [275]	validation-rmse:6.45665
# [276]	validation-rmse:6.45648
# [277]	validation-rmse:6.45634
# [278]	validation-rmse:6.45603
# [279]	validation-rmse:6.45583
# [280]	validation-rmse:6.45566
# [281]	validation-rmse:6.45558
# [282]	validation-rmse:6.45544
# [283]	validation-rmse:6.45501
# [284]	validation-rmse:6.45480
# [285]	validation-rmse:6.45460
# [286]	validation-rmse:6.45435
# [287]	validation-rmse:6.45422
# [288]	validation-rmse:6.45414
# [289]	validation-rmse:6.45397
# [290]	validation-rmse:6.45406
# [291]	validation-rmse:6.45387
# [292]	validation-rmse:6.45363
# [293]	validation-rmse:6.45345
# [294]	validation-rmse:6.45327
# [295]	validation-rmse:6.45314
# [296]	validation-rmse:6.45306
# [297]	validation-rmse:6.45284
# [298]	validation-rmse:6.45295
# [299]	validation-rmse:6.45301
# [300]	validation-rmse:6.45207
# [301]	validation-rmse:6.45190
# [302]	validation-rmse:6.45171
# [303]	validation-rmse:6.45171
# [304]	validation-rmse:6.45151
# [305]	validation-rmse:6.45138
# [306]	validation-rmse:6.45134
# [307]	validation-rmse:6.45108
# [308]	validation-rmse:6.45105
# [309]	validation-rmse:6.45081
# [310]	validation-rmse:6.45034
# [311]	validation-rmse:6.45031
# [312]	validation-rmse:6.45014
# [313]	validation-rmse:6.44999
# [314]	validation-rmse:6.45001
# [315]	validation-rmse:6.44984
# [316]	validation-rmse:6.44969
# [317]	validation-rmse:6.44947
# [318]	validation-rmse:6.44925
# [319]	validation-rmse:6.44876
# [320]	validation-rmse:6.44864
# [321]	validation-rmse:6.44846
# [322]	validation-rmse:6.44817
# [323]	validation-rmse:6.44795
# [324]	validation-rmse:6.44767
# [325]	validation-rmse:6.44746
# [326]	validation-rmse:6.44725
# [327]	validation-rmse:6.44709
# [328]	validation-rmse:6.44687
# [329]	validation-rmse:6.44665
# [330]	validation-rmse:6.44620
# [331]	validation-rmse:6.44604
# [332]	validation-rmse:6.44582
# [333]	validation-rmse:6.44583
# [334]	validation-rmse:6.44555
# [335]	validation-rmse:6.44528
# [336]	validation-rmse:6.44522
# [337]	validation-rmse:6.44519
# [338]	validation-rmse:6.44492
# [339]	validation-rmse:6.44473
# [340]	validation-rmse:6.44454
# [341]	validation-rmse:6.44444
# [342]	validation-rmse:6.44425
# [343]	validation-rmse:6.44397
# [344]	validation-rmse:6.44393
# [345]	validation-rmse:6.44375
# [346]	validation-rmse:6.44360
# [347]	validation-rmse:6.44360
# [348]	validation-rmse:6.44342
# [349]	validation-rmse:6.44342
# [350]	validation-rmse:6.44330
# [351]	validation-rmse:6.44304
# [352]	validation-rmse:6.44290
# [353]	validation-rmse:6.44275
# [354]	validation-rmse:6.44269
# [355]	validation-rmse:6.44258
# [356]	validation-rmse:6.44257
# [357]	validation-rmse:6.44259
# [358]	validation-rmse:6.44246
# [359]	validation-rmse:6.44238
# [360]	validation-rmse:6.44184
# [361]	validation-rmse:6.44169
# [362]	validation-rmse:6.44154
# [363]	validation-rmse:6.44137
# [364]	validation-rmse:6.44125
# [365]	validation-rmse:6.44140
# [366]	validation-rmse:6.44144
# [367]	validation-rmse:6.44131
# [368]	validation-rmse:6.44117
# [369]	validation-rmse:6.44112
# [370]	validation-rmse:6.44095
# [371]	validation-rmse:6.44100
# [372]	validation-rmse:6.44083
# [373]	validation-rmse:6.44068
# [374]	validation-rmse:6.44060
# [375]	validation-rmse:6.44038
# [376]	validation-rmse:6.44023
# [377]	validation-rmse:6.44003
# [378]	validation-rmse:6.43985
# [379]	validation-rmse:6.43966
# [380]	validation-rmse:6.43960
# [381]	validation-rmse:6.43952
# [382]	validation-rmse:6.43923
# [383]	validation-rmse:6.43911
# [384]	validation-rmse:6.43892
# [385]	validation-rmse:6.43900
# [386]	validation-rmse:6.43905
# [387]	validation-rmse:6.43883
# [388]	validation-rmse:6.43866
# [389]	validation-rmse:6.43860
# [390]	validation-rmse:6.43840
# [391]	validation-rmse:6.43832
# [392]	validation-rmse:6.43812
# [393]	validation-rmse:6.43795
# [394]	validation-rmse:6.43784
# [395]	validation-rmse:6.43766
# [396]	validation-rmse:6.43742
# [397]	validation-rmse:6.43721
# [398]	validation-rmse:6.43699
# [399]	validation-rmse:6.43684
# [400]	validation-rmse:6.43668
# [401]	validation-rmse:6.43660
# [402]	validation-rmse:6.43652
# [403]	validation-rmse:6.43641
# [404]	validation-rmse:6.43631
# [405]	validation-rmse:6.43608
# [406]	validation-rmse:6.43605
# [407]	validation-rmse:6.43596
# [408]	validation-rmse:6.43594
# [409]	validation-rmse:6.43584
# [410]	validation-rmse:6.43565
# [411]	validation-rmse:6.43561
# [412]	validation-rmse:6.43542
# [413]	validation-rmse:6.43526
# [414]	validation-rmse:6.43501
# [415]	validation-rmse:6.43482
# [416]	validation-rmse:6.43487
# [417]	validation-rmse:6.43485
# [418]	validation-rmse:6.43487
# [419]	validation-rmse:6.43475
# [420]	validation-rmse:6.43461
# [421]	validation-rmse:6.43441
# [422]	validation-rmse:6.43429
# [423]	validation-rmse:6.43417
# [424]	validation-rmse:6.43405
# [425]	validation-rmse:6.43386
# [426]	validation-rmse:6.43364
# [427]	validation-rmse:6.43347
# [428]	validation-rmse:6.43339
# [429]	validation-rmse:6.43335
# [430]	validation-rmse:6.43318
# [431]	validation-rmse:6.43308
# [432]	validation-rmse:6.43275
# [433]	validation-rmse:6.43290
# [434]	validation-rmse:6.43273
# [435]	validation-rmse:6.43264
# [436]	validation-rmse:6.43257
# [437]	validation-rmse:6.43245
# [438]	validation-rmse:6.43252
# [439]	validation-rmse:6.43232
# [440]	validation-rmse:6.43220
# [441]	validation-rmse:6.43221
# [442]	validation-rmse:6.43215
# [443]	validation-rmse:6.43213
# [444]	validation-rmse:6.43206
# [445]	validation-rmse:6.43190
# [446]	validation-rmse:6.43186
# [447]	validation-rmse:6.43176
# [448]	validation-rmse:6.43158
# [449]	validation-rmse:6.43157
# [450]	validation-rmse:6.43158
# [451]	validation-rmse:6.43149
# [452]	validation-rmse:6.43125
# [453]	validation-rmse:6.43116
# [454]	validation-rmse:6.43097
# [455]	validation-rmse:6.43086
# [456]	validation-rmse:6.43078
# [457]	validation-rmse:6.43065
# [458]	validation-rmse:6.43040
# [459]	validation-rmse:6.43048
# [460]	validation-rmse:6.43030
# [461]	validation-rmse:6.43016
# [462]	validation-rmse:6.43014
# [463]	validation-rmse:6.43021
# [464]	validation-rmse:6.43023
# [465]	validation-rmse:6.43018
# [466]	validation-rmse:6.43026
# [467]	validation-rmse:6.42998
# [468]	validation-rmse:6.42979
# [469]	validation-rmse:6.42974
# [470]	validation-rmse:6.42964
# [471]	validation-rmse:6.42960
# [472]	validation-rmse:6.42952
# [473]	validation-rmse:6.42936
# [474]	validation-rmse:6.42918
# [475]	validation-rmse:6.42902
# [476]	validation-rmse:6.42884
# [477]	validation-rmse:6.42879
# [478]	validation-rmse:6.42870
# [479]	validation-rmse:6.42840
# [480]	validation-rmse:6.42843
# [481]	validation-rmse:6.42822
# [482]	validation-rmse:6.42808
# [483]	validation-rmse:6.42795
# [484]	validation-rmse:6.42777
# [485]	validation-rmse:6.42770
# [486]	validation-rmse:6.42753
# [487]	validation-rmse:6.42751
# [488]	validation-rmse:6.42735
# [489]	validation-rmse:6.42722
# [490]	validation-rmse:6.42703
# [491]	validation-rmse:6.42691
# [492]	validation-rmse:6.42682
# [493]	validation-rmse:6.42678
# [494]	validation-rmse:6.42667
# [495]	validation-rmse:6.42663
# [496]	validation-rmse:6.42662
# [497]	validation-rmse:6.42651
# [498]	validation-rmse:6.42613
# [499]	validation-rmse:6.42602
# [500]	validation-rmse:6.42583
# [501]	validation-rmse:6.42562
# [502]	validation-rmse:6.42552
# [503]	validation-rmse:6.42533
# [504]	validation-rmse:6.42519
# [505]	validation-rmse:6.42511
# [506]	validation-rmse:6.42495
# [507]	validation-rmse:6.42473
# [508]	validation-rmse:6.42476
# [509]	validation-rmse:6.42463
# [510]	validation-rmse:6.42444
# [511]	validation-rmse:6.42444
# [512]	validation-rmse:6.42478
# [513]	validation-rmse:6.42490
# [514]	validation-rmse:6.42427
# [515]	validation-rmse:6.42422
# [516]	validation-rmse:6.42415
# [517]	validation-rmse:6.42401
# [518]	validation-rmse:6.42390
# [519]	validation-rmse:6.42370
# [520]	validation-rmse:6.42362
# [521]	validation-rmse:6.42363
# [522]	validation-rmse:6.42348
# [523]	validation-rmse:6.42337
# [524]	validation-rmse:6.42328
# [525]	validation-rmse:6.42332
# [526]	validation-rmse:6.42347
# [527]	validation-rmse:6.42332
# [528]	validation-rmse:6.42317
# [529]	validation-rmse:6.42324
# [530]	validation-rmse:6.42308
# [531]	validation-rmse:6.42289
# [532]	validation-rmse:6.42290
# [533]	validation-rmse:6.42294
# [534]	validation-rmse:6.42295
# [535]	validation-rmse:6.42298
# [536]	validation-rmse:6.42297
# [537]	validation-rmse:6.42274
# [538]	validation-rmse:6.42270
# [539]	validation-rmse:6.42244
# [540]	validation-rmse:6.42233
# [541]	validation-rmse:6.42225
# [542]	validation-rmse:6.42217
# [543]	validation-rmse:6.42215
# [544]	validation-rmse:6.42208
# [545]	validation-rmse:6.42193
# [546]	validation-rmse:6.42183
# [547]	validation-rmse:6.42176
# [548]	validation-rmse:6.42175
# [549]	validation-rmse:6.42165
# [550]	validation-rmse:6.42162
# [551]	validation-rmse:6.42153
# [552]	validation-rmse:6.42166
# [553]	validation-rmse:6.42163
# [554]	validation-rmse:6.42140
# [555]	validation-rmse:6.42135
# [556]	validation-rmse:6.42130
# [557]	validation-rmse:6.42128
# [558]	validation-rmse:6.42121
# [559]	validation-rmse:6.42123
# [560]	validation-rmse:6.42113
# [561]	validation-rmse:6.42092
# [562]	validation-rmse:6.42076
# [563]	validation-rmse:6.42072
# [564]	validation-rmse:6.42052
# [565]	validation-rmse:6.42035
# [566]	validation-rmse:6.42031
# [567]	validation-rmse:6.42024
# [568]	validation-rmse:6.42004
# [569]	validation-rmse:6.42000
# [570]	validation-rmse:6.41996
# [571]	validation-rmse:6.41977
# [572]	validation-rmse:6.41982
# [573]	validation-rmse:6.41968
# [574]	validation-rmse:6.41958
# [575]	validation-rmse:6.41939
# [576]	validation-rmse:6.41941
# [577]	validation-rmse:6.41939
# [578]	validation-rmse:6.41922
# [579]	validation-rmse:6.41908
# [580]	validation-rmse:6.41896
# [581]	validation-rmse:6.41884
# [582]	validation-rmse:6.41872
# [583]	validation-rmse:6.41862
# [584]	validation-rmse:6.41844
# [585]	validation-rmse:6.41833
# [586]	validation-rmse:6.41828
# [587]	validation-rmse:6.41821
# [588]	validation-rmse:6.41801
# [589]	validation-rmse:6.41798
# [590]	validation-rmse:6.41807
# [591]	validation-rmse:6.41787
# [592]	validation-rmse:6.41775
# [593]	validation-rmse:6.41773
# [594]	validation-rmse:6.41779
# [595]	validation-rmse:6.41802
# [596]	validation-rmse:6.41787
# [597]	validation-rmse:6.41739
# [598]	validation-rmse:6.41715
# [599]	validation-rmse:6.41694
# [600]	validation-rmse:6.41684
# [601]	validation-rmse:6.41674
# [602]	validation-rmse:6.41666
# [603]	validation-rmse:6.41661
# [604]	validation-rmse:6.41661
# [605]	validation-rmse:6.41646
# [606]	validation-rmse:6.41634
# [607]	validation-rmse:6.41620
# [608]	validation-rmse:6.41615
# [609]	validation-rmse:6.41600
# [610]	validation-rmse:6.41590
# [611]	validation-rmse:6.41587
# [612]	validation-rmse:6.41582
# [613]	validation-rmse:6.41588
# [614]	validation-rmse:6.41589
# [615]	validation-rmse:6.41591
# [616]	validation-rmse:6.41584
# [617]	validation-rmse:6.41603
# [618]	validation-rmse:6.41599
# [619]	validation-rmse:6.41594
# [620]	validation-rmse:6.41582
# [621]	validation-rmse:6.41576
# [622]	validation-rmse:6.41586
# [623]	validation-rmse:6.41586
# [624]	validation-rmse:6.41588
# [625]	validation-rmse:6.41572
# [626]	validation-rmse:6.41543
# [627]	validation-rmse:6.41536
# [628]	validation-rmse:6.41536
# [629]	validation-rmse:6.41534
# [630]	validation-rmse:6.41525
# [631]	validation-rmse:6.41520
# [632]	validation-rmse:6.41520
# [633]	validation-rmse:6.41514
# [634]	validation-rmse:6.41467
# [635]	validation-rmse:6.41468
# [636]	validation-rmse:6.41459
# [637]	validation-rmse:6.41452
# [638]	validation-rmse:6.41446
# [639]	validation-rmse:6.41450
# [640]	validation-rmse:6.41434
# [641]	validation-rmse:6.41420
# [642]	validation-rmse:6.41412
# [643]	validation-rmse:6.41404
# [644]	validation-rmse:6.41401
# [645]	validation-rmse:6.41407
# [646]	validation-rmse:6.41409
# [647]	validation-rmse:6.41433
# [648]	validation-rmse:6.41424
# [649]	validation-rmse:6.41436
# [650]	validation-rmse:6.41433
# [651]	validation-rmse:6.41434
# [652]	validation-rmse:6.41432
# [653]	validation-rmse:6.41413
# [654]	validation-rmse:6.41394
# [655]	validation-rmse:6.41387
# [656]	validation-rmse:6.41388
# [657]	validation-rmse:6.41376
# [658]	validation-rmse:6.41371
# [659]	validation-rmse:6.41364
# [660]	validation-rmse:6.41358
# [661]	validation-rmse:6.41358
# [662]	validation-rmse:6.41355
# [663]	validation-rmse:6.41350
# [664]	validation-rmse:6.41330
# [665]	validation-rmse:6.41308
# [666]	validation-rmse:6.41306
# [667]	validation-rmse:6.41295
# [668]	validation-rmse:6.41294
# [669]	validation-rmse:6.41295
# [670]	validation-rmse:6.41282
# [671]	validation-rmse:6.41271
# [672]	validation-rmse:6.41259
# [673]	validation-rmse:6.41258
# [674]	validation-rmse:6.41236
# [675]	validation-rmse:6.41244
# [676]	validation-rmse:6.41241
# [677]	validation-rmse:6.41233
# [678]	validation-rmse:6.41213
# [679]	validation-rmse:6.41235
# [680]	validation-rmse:6.41215
# [681]	validation-rmse:6.41195
# [682]	validation-rmse:6.41176
# [683]	validation-rmse:6.41175
# [684]	validation-rmse:6.41170
# [685]	validation-rmse:6.41162
# [686]	validation-rmse:6.41162
# [687]	validation-rmse:6.41149
# [688]	validation-rmse:6.41144
# [689]	validation-rmse:6.41128
# [690]	validation-rmse:6.41113
# [691]	validation-rmse:6.41115
# [692]	validation-rmse:6.41152
# [693]	validation-rmse:6.41102
# [694]	validation-rmse:6.41091
# [695]	validation-rmse:6.41087
# [696]	validation-rmse:6.41080
# [697]	validation-rmse:6.41076
# [698]	validation-rmse:6.41061
# [699]	validation-rmse:6.41050
# [700]	validation-rmse:6.41033
# [701]	validation-rmse:6.41032
# [702]	validation-rmse:6.41025
# [703]	validation-rmse:6.41018
# [704]	validation-rmse:6.41020
# [705]	validation-rmse:6.41012
# [706]	validation-rmse:6.41004
# [707]	validation-rmse:6.41004
# [708]	validation-rmse:6.41004
# [709]	validation-rmse:6.41004
# [710]	validation-rmse:6.40998
# [711]	validation-rmse:6.40985
# [712]	validation-rmse:6.40989
# [713]	validation-rmse:6.40981
# [714]	validation-rmse:6.40965
# [715]	validation-rmse:6.40963
# [716]	validation-rmse:6.40966
# [717]	validation-rmse:6.40954
# [718]	validation-rmse:6.40951
# [719]	validation-rmse:6.40945
# [720]	validation-rmse:6.40937
# [721]	validation-rmse:6.40947
# [722]	validation-rmse:6.40939
# [723]	validation-rmse:6.40933
# [724]	validation-rmse:6.40925
# [725]	validation-rmse:6.40918
# [726]	validation-rmse:6.40892
# [727]	validation-rmse:6.40904
# [728]	validation-rmse:6.40909
# [729]	validation-rmse:6.40910
# [730]	validation-rmse:6.40902
# [731]	validation-rmse:6.40907
# [732]	validation-rmse:6.40910
# [733]	validation-rmse:6.40905
# [734]	validation-rmse:6.40892
# [735]	validation-rmse:6.40893
# [736]	validation-rmse:6.40886
# [737]	validation-rmse:6.40879
# [738]	validation-rmse:6.40864
# [739]	validation-rmse:6.40855
# [740]	validation-rmse:6.40866
# [741]	validation-rmse:6.40860
# [742]	validation-rmse:6.40849
# [743]	validation-rmse:6.40832
# [744]	validation-rmse:6.40827
# [745]	validation-rmse:6.40824
# [746]	validation-rmse:6.40815
# [747]	validation-rmse:6.40822
# [748]	validation-rmse:6.40833
# [749]	validation-rmse:6.40836
# [750]	validation-rmse:6.40830
# [751]	validation-rmse:6.40860
# [752]	validation-rmse:6.40854
# [753]	validation-rmse:6.40855
# [754]	validation-rmse:6.40849
# [755]	validation-rmse:6.40824
# [756]	validation-rmse:6.40820
# [757]	validation-rmse:6.40822
# [758]	validation-rmse:6.40810
# [759]	validation-rmse:6.40802
# [760]	validation-rmse:6.40798
# [761]	validation-rmse:6.40796
# [762]	validation-rmse:6.40794
# [763]	validation-rmse:6.40802
# [764]	validation-rmse:6.40813
# [765]	validation-rmse:6.40808
# [766]	validation-rmse:6.40811
# [767]	validation-rmse:6.40806
# [768]	validation-rmse:6.40803
# [769]	validation-rmse:6.40795
# [770]	validation-rmse:6.40794
# [771]	validation-rmse:6.40787
# [772]	validation-rmse:6.40785
# [773]	validation-rmse:6.40771
# [774]	validation-rmse:6.40765
# [775]	validation-rmse:6.40755
# [776]	validation-rmse:6.40753
# [777]	validation-rmse:6.40754
# [778]	validation-rmse:6.40746
# [779]	validation-rmse:6.40738
# [780]	validation-rmse:6.40733
# [781]	validation-rmse:6.40721
# [782]	validation-rmse:6.40715
# [783]	validation-rmse:6.40700
# [784]	validation-rmse:6.40690
# [785]	validation-rmse:6.40703
# [786]	validation-rmse:6.40718
# [787]	validation-rmse:6.40714
# [788]	validation-rmse:6.40725
# [789]	validation-rmse:6.40713
# [790]	validation-rmse:6.40712
# [791]	validation-rmse:6.40701
# [792]	validation-rmse:6.40689
# [793]	validation-rmse:6.40680
# [794]	validation-rmse:6.40667
# [795]	validation-rmse:6.40661
# [796]	validation-rmse:6.40657
# [797]	validation-rmse:6.40657
# [798]	validation-rmse:6.40661
# [799]	validation-rmse:6.40662
# [800]	validation-rmse:6.40647
# [801]	validation-rmse:6.40639
# [802]	validation-rmse:6.40636
# [803]	validation-rmse:6.40631
# [804]	validation-rmse:6.40637
# [805]	validation-rmse:6.40632
# [806]	validation-rmse:6.40620
# [807]	validation-rmse:6.40610
# [808]	validation-rmse:6.40601
# [809]	validation-rmse:6.40601
# [810]	validation-rmse:6.40600
# [811]	validation-rmse:6.40612
# [812]	validation-rmse:6.40600
# [813]	validation-rmse:6.40590
# [814]	validation-rmse:6.40586
# [815]	validation-rmse:6.40583
# [816]	validation-rmse:6.40583
# [817]	validation-rmse:6.40596
# [818]	validation-rmse:6.40599
# [819]	validation-rmse:6.40590
# [820]	validation-rmse:6.40590
# [821]	validation-rmse:6.40586
# [822]	validation-rmse:6.40578
# [823]	validation-rmse:6.40567
# [824]	validation-rmse:6.40565
# [825]	validation-rmse:6.40564
# [826]	validation-rmse:6.40553
# [827]	validation-rmse:6.40549
# [828]	validation-rmse:6.40551
# [829]	validation-rmse:6.40547
# [830]	validation-rmse:6.40561
# [831]	validation-rmse:6.40560
# [832]	validation-rmse:6.40550
# [833]	validation-rmse:6.40547
# [834]	validation-rmse:6.40548
# [835]	validation-rmse:6.40543
# [836]	validation-rmse:6.40550
# [837]	validation-rmse:6.40538
# [838]	validation-rmse:6.40535
# [839]	validation-rmse:6.40529
# [840]	validation-rmse:6.40543
# [841]	validation-rmse:6.40567
# [842]	validation-rmse:6.40556
# [843]	validation-rmse:6.40544
# [844]	validation-rmse:6.40541
# [845]	validation-rmse:6.40551
# [846]	validation-rmse:6.40573
# [847]	validation-rmse:6.40563
# [848]	validation-rmse:6.40561
# [849]	validation-rmse:6.40557
# [850]	validation-rmse:6.40556
# [851]	validation-rmse:6.40558
# [852]	validation-rmse:6.40544
# [853]	validation-rmse:6.40536
# [854]	validation-rmse:6.40530
# [855]	validation-rmse:6.40522
# [856]	validation-rmse:6.40506
# [857]	validation-rmse:6.40505
# [858]	validation-rmse:6.40504
# [859]	validation-rmse:6.40490
# [860]	validation-rmse:6.40474
# [861]	validation-rmse:6.40469
# [862]	validation-rmse:6.40468
# [863]	validation-rmse:6.40457
# [864]	validation-rmse:6.40461
# [865]	validation-rmse:6.40470
# ...
# [57]	validation-rmse:6.52629
# [58]	validation-rmse:6.52644
# [59]	validation-rmse:6.52580
# [60]	validation-rmse:6.52517
# [61]	validation-rmse:6.52481
# [62]	validation-rmse:6.52490
# [63]	validation-rmse:6.52523
# [64]	validation-rmse:6.52422
# [65]	validation-rmse:6.52509
# [66]	validation-rmse:6.52461
# [67]	validation-rmse:6.52479
# [68]	validation-rmse:6.52348
# [69]	validation-rmse:6.52339
# [70]	validation-rmse:6.52323
# [71]	validation-rmse:6.52291
# [72]	validation-rmse:6.52348
# [73]	validation-rmse:6.52314
# [74]	validation-rmse:6.52303
# [75]	validation-rmse:6.52267
# [76]	validation-rmse:6.52358
# [77]	validation-rmse:6.52373
# [78]	validation-rmse:6.52372
# [79]	validation-rmse:6.52328
# [80]	validation-rmse:6.52246
# [81]	validation-rmse:6.52325
# [82]	validation-rmse:6.52309
# [83]	validation-rmse:6.52266
# [84]	validation-rmse:6.52270
# [85]	validation-rmse:6.52167
# [86]	validation-rmse:6.52189
# [87]	validation-rmse:6.52148
# [88]	validation-rmse:6.52215
# [89]	validation-rmse:6.52210
# [90]	validation-rmse:6.52212
# [91]	validation-rmse:6.52173
# [92]	validation-rmse:6.52169
# [93]	validation-rmse:6.52107
# [94]	validation-rmse:6.52111
# [95]	validation-rmse:6.52050
# [96]	validation-rmse:6.52061
# [97]	validation-rmse:6.51986
# [98]	validation-rmse:6.51927
# [99]	validation-rmse:6.51894
# [100]	validation-rmse:6.51953
# [101]	validation-rmse:6.52039
# [102]	validation-rmse:6.51957
# [103]	validation-rmse:6.51977
# [104]	validation-rmse:6.51948
# [105]	validation-rmse:6.51936
# [106]	validation-rmse:6.51948
# [107]	validation-rmse:6.51902
# [108]	validation-rmse:6.51864
# [109]	validation-rmse:6.51845
# [110]	validation-rmse:6.51893
# [111]	validation-rmse:6.51899
# [112]	validation-rmse:6.51879
# [113]	validation-rmse:6.51784
# [114]	validation-rmse:6.51786
# [115]	validation-rmse:6.51639
# [116]	validation-rmse:6.51623
# [117]	validation-rmse:6.51666
# [118]	validation-rmse:6.51636
# [119]	validation-rmse:6.51623
# [120]	validation-rmse:6.51670
# [121]	validation-rmse:6.51591
# [122]	validation-rmse:6.51610
# [123]	validation-rmse:6.51559
# [124]	validation-rmse:6.51553
# [125]	validation-rmse:6.51528
# [126]	validation-rmse:6.51423
# [127]	validation-rmse:6.51490
# [128]	validation-rmse:6.51480
# [129]	validation-rmse:6.51551
# [130]	validation-rmse:6.51521
# [131]	validation-rmse:6.51448
# [132]	validation-rmse:6.51493
# [133]	validation-rmse:6.51415
# [134]	validation-rmse:6.51410
# [135]	validation-rmse:6.51391
# [136]	validation-rmse:6.51405
# [137]	validation-rmse:6.51444
# [138]	validation-rmse:6.51399
# [139]	validation-rmse:6.51444
# [140]	validation-rmse:6.51364
# [141]	validation-rmse:6.51339
# [142]	validation-rmse:6.51383
# [143]	validation-rmse:6.51411
# [144]	validation-rmse:6.51297
# [145]	validation-rmse:6.51317
# [146]	validation-rmse:6.51329
# [147]	validation-rmse:6.51333
# [148]	validation-rmse:6.51305
# [149]	validation-rmse:6.51308
# [150]	validation-rmse:6.51343
# [151]	validation-rmse:6.51319
# [152]	validation-rmse:6.51346
# [153]	validation-rmse:6.51338
# [154]	validation-rmse:6.51270
# [155]	validation-rmse:6.51289
# [156]	validation-rmse:6.51307
# [157]	validation-rmse:6.51251
# [158]	validation-rmse:6.51282
# [159]	validation-rmse:6.51280
# [160]	validation-rmse:6.51305
# [161]	validation-rmse:6.51282
# [162]	validation-rmse:6.51306
# [163]	validation-rmse:6.51255
# [164]	validation-rmse:6.51353
# [165]	validation-rmse:6.51317
# [166]	validation-rmse:6.51292
# [167]	validation-rmse:6.51299
# [168]	validation-rmse:6.51292
# [169]	validation-rmse:6.51282
# [170]	validation-rmse:6.51334
# [171]	validation-rmse:6.51263
# [172]	validation-rmse:6.51317
# [173]	validation-rmse:6.51340
# [174]	validation-rmse:6.51284
# [175]	validation-rmse:6.51350
# [176]	validation-rmse:6.51317
# [177]	validation-rmse:6.51350
# [178]	validation-rmse:6.51361
# [179]	validation-rmse:6.51337
# [180]	validation-rmse:6.51299
# [181]	validation-rmse:6.51341
# [182]	validation-rmse:6.51320
# [183]	validation-rmse:6.51290
# [184]	validation-rmse:6.51299
# [185]	validation-rmse:6.51310
# [186]	validation-rmse:6.51368
# [187]	validation-rmse:6.51331
# [188]	validation-rmse:6.51296
# [189]	validation-rmse:6.51331
# [190]	validation-rmse:6.51370
# [191]	validation-rmse:6.51369
# [192]	validation-rmse:6.51366
# [193]	validation-rmse:6.51308
# [194]	validation-rmse:6.51392
# [195]	validation-rmse:6.51333
# [196]	validation-rmse:6.51388
# [197]	validation-rmse:6.51376
# [198]	validation-rmse:6.51346
# [199]	validation-rmse:6.51261
# [200]	validation-rmse:6.51149
# [201]	validation-rmse:6.51193
# [202]	validation-rmse:6.51148
# [203]	validation-rmse:6.51182
# [204]	validation-rmse:6.51183
# [205]	validation-rmse:6.51175
# [206]	validation-rmse:6.51227
# [207]	validation-rmse:6.51257
# [208]	validation-rmse:6.51271
# [209]	validation-rmse:6.51248
# [210]	validation-rmse:6.51237
# [211]	validation-rmse:6.51212
# [212]	validation-rmse:6.51211
# [213]	validation-rmse:6.51189
# [214]	validation-rmse:6.51173
# [215]	validation-rmse:6.51228
# [216]	validation-rmse:6.51215
# [217]	validation-rmse:6.51179
# [218]	validation-rmse:6.51248
# [219]	validation-rmse:6.51317
# [220]	validation-rmse:6.51261
# [221]	validation-rmse:6.51196
# [222]	validation-rmse:6.51284
# [223]	validation-rmse:6.51330
# [224]	validation-rmse:6.51324
# [225]	validation-rmse:6.51291
# [226]	validation-rmse:6.51296
# [227]	validation-rmse:6.51326
# [228]	validation-rmse:6.51332
# [229]	validation-rmse:6.51271
# [230]	validation-rmse:6.51314
# [231]	validation-rmse:6.51264
# [232]	validation-rmse:6.51236
# [233]	validation-rmse:6.51266
# [234]	validation-rmse:6.51258
# [235]	validation-rmse:6.51286
# [236]	validation-rmse:6.51262
# [237]	validation-rmse:6.51220
# [238]	validation-rmse:6.51176
# [239]	validation-rmse:6.51202
# [240]	validation-rmse:6.51224
# [241]	validation-rmse:6.51198
# [242]	validation-rmse:6.51206
# [243]	validation-rmse:6.51182
# [244]	validation-rmse:6.51221
# [245]	validation-rmse:6.51185
# [246]	validation-rmse:6.51230
# [247]	validation-rmse:6.51224
# [248]	validation-rmse:6.51253
# [249]	validation-rmse:6.51229
# [250]	validation-rmse:6.51228
# [251]	validation-rmse:6.51195
# [252]	validation-rmse:6.51235
# 100%|██████████| 50/50 [23:27<00:00, 28.16s/trial, best loss: 6.308055921362512]

# %% [markdown]
# ## 3.0 Autlog

# %%
# autlog is a function that automatically logs the parameters, metrics and artifacts of the model
# it is a very useful function that can be used to log the model without having to write the code
# it only works with certain models, like xgboost, lightgbm and catboost ---> check website for full list


# you can disable autologging by using the disable parameter if you don't want to log the model
# mlflow.xgboost.autolog(disable=True)

# %% [markdown]
# ## 4.0 Model management

# %%
with mlflow.start_run():

    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    # we can use the best result from the hyperopt optimization
    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    # log the parameters to mlflow
    mlflow.log_params(best_params)

    # we can use the best parameters to train the model
    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    # once the model is trained, we can save it and make predictions
    y_pred = booster.predict(valid)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

    # we will export the preprocessor as well
    # the preprocessor is the DictVectorizer we used to transform the data
    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)

    # log the preprocessor - the dictvectorizer, to mlflow
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# /usr/local/anaconda3/lib/python3.12/site-packages/xgboost/callback.py:386: UserWarning: [12:25:18] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation-rmse:11.44482
# [1]	validation-rmse:10.77202
# [2]	validation-rmse:10.18363
# [3]	validation-rmse:9.67396
# [4]	validation-rmse:9.23166
# [5]	validation-rmse:8.84808
# [6]	validation-rmse:8.51883
# [7]	validation-rmse:8.23597
# [8]	validation-rmse:7.99320
# [9]	validation-rmse:7.78709
# [10]	validation-rmse:7.61022
# [11]	validation-rmse:7.45952
# [12]	validation-rmse:7.33049
# [13]	validation-rmse:7.22098
# [14]	validation-rmse:7.12713
# [15]	validation-rmse:7.04752
# [16]	validation-rmse:6.98005
# [17]	validation-rmse:6.92232
# [18]	validation-rmse:6.87112
# [19]	validation-rmse:6.82740
# [20]	validation-rmse:6.78995
# [21]	validation-rmse:6.75792
# [22]	validation-rmse:6.72994
# [23]	validation-rmse:6.70547
# [24]	validation-rmse:6.68390
# [25]	validation-rmse:6.66421
# [26]	validation-rmse:6.64806
# [27]	validation-rmse:6.63280
# [28]	validation-rmse:6.61924
# [29]	validation-rmse:6.60773
# [30]	validation-rmse:6.59777
# [31]	validation-rmse:6.58875
# [32]	validation-rmse:6.58107
# [33]	validation-rmse:6.57217
# [34]	validation-rmse:6.56557
# [35]	validation-rmse:6.56003
# [36]	validation-rmse:6.55392
# [37]	validation-rmse:6.54924
# [38]	validation-rmse:6.54536
# [39]	validation-rmse:6.54187
# [40]	validation-rmse:6.53873
# [41]	validation-rmse:6.53518
# [42]	validation-rmse:6.53287
# [43]	validation-rmse:6.53048
# [44]	validation-rmse:6.52858
# [45]	validation-rmse:6.52703
# [46]	validation-rmse:6.52566
# [47]	validation-rmse:6.52419
# [48]	validation-rmse:6.52323
# [49]	validation-rmse:6.52265
# [50]	validation-rmse:6.52202
# [51]	validation-rmse:6.52036
# [52]	validation-rmse:6.52003
# [53]	validation-rmse:6.51962
# [54]	validation-rmse:6.51829
# [55]	validation-rmse:6.51712
# [56]	validation-rmse:6.51598
# [57]	validation-rmse:6.51517
# [58]	validation-rmse:6.51442
# [59]	validation-rmse:6.51357
# [60]	validation-rmse:6.51194
# [61]	validation-rmse:6.51127
# [62]	validation-rmse:6.51044
# [63]	validation-rmse:6.50930
# [64]	validation-rmse:6.50840
# [65]	validation-rmse:6.50731
# [66]	validation-rmse:6.50635
# [67]	validation-rmse:6.50566
# [68]	validation-rmse:6.50458
# [69]	validation-rmse:6.50339
# [70]	validation-rmse:6.50239
# [71]	validation-rmse:6.50137
# [72]	validation-rmse:6.50014
# [73]	validation-rmse:6.49940
# [74]	validation-rmse:6.49835
# [75]	validation-rmse:6.49782
# [76]	validation-rmse:6.49697
# [77]	validation-rmse:6.49628
# [78]	validation-rmse:6.49561
# [79]	validation-rmse:6.49495
# [80]	validation-rmse:6.49429
# [81]	validation-rmse:6.49371
# [82]	validation-rmse:6.49317
# [83]	validation-rmse:6.49248
# [84]	validation-rmse:6.49170
# [85]	validation-rmse:6.49080
# [86]	validation-rmse:6.49020
# [87]	validation-rmse:6.48927
# [88]	validation-rmse:6.48842
# [89]	validation-rmse:6.48717
# [90]	validation-rmse:6.48666
# [91]	validation-rmse:6.48608
# [92]	validation-rmse:6.48531
# [93]	validation-rmse:6.48457
# [94]	validation-rmse:6.48376
# [95]	validation-rmse:6.48304
# [96]	validation-rmse:6.48246
# [97]	validation-rmse:6.48113
# [98]	validation-rmse:6.48052
# [99]	validation-rmse:6.47984
# [100]	validation-rmse:6.47922
# [101]	validation-rmse:6.47886
# [102]	validation-rmse:6.47819
# [103]	validation-rmse:6.47742
# [104]	validation-rmse:6.47685
# [105]	validation-rmse:6.47643
# [106]	validation-rmse:6.47616
# [107]	validation-rmse:6.47583
# [108]	validation-rmse:6.47530
# [109]	validation-rmse:6.47479
# [110]	validation-rmse:6.47409
# [111]	validation-rmse:6.47339
# [112]	validation-rmse:6.47296
# [113]	validation-rmse:6.47250
# [114]	validation-rmse:6.47148
# [115]	validation-rmse:6.47089
# [116]	validation-rmse:6.47037
# [117]	validation-rmse:6.46947
# [118]	validation-rmse:6.46907
# [119]	validation-rmse:6.46840
# [120]	validation-rmse:6.46749
# [121]	validation-rmse:6.46701
# [122]	validation-rmse:6.46612
# [123]	validation-rmse:6.46538
# [124]	validation-rmse:6.46467
# [125]	validation-rmse:6.46413
# [126]	validation-rmse:6.46350
# [127]	validation-rmse:6.46265
# [128]	validation-rmse:6.46225
# [129]	validation-rmse:6.46169
# [130]	validation-rmse:6.46065
# [131]	validation-rmse:6.46022
# [132]	validation-rmse:6.45980
# [133]	validation-rmse:6.45918
# [134]	validation-rmse:6.45844
# [135]	validation-rmse:6.45802
# [136]	validation-rmse:6.45783
# [137]	validation-rmse:6.45746
# [138]	validation-rmse:6.45661
# [139]	validation-rmse:6.45619
# [140]	validation-rmse:6.45566
# [141]	validation-rmse:6.45554
# [142]	validation-rmse:6.45487
# [143]	validation-rmse:6.45461
# [144]	validation-rmse:6.45411
# [145]	validation-rmse:6.45325
# [146]	validation-rmse:6.45278
# [147]	validation-rmse:6.45215
# [148]	validation-rmse:6.45174
# [149]	validation-rmse:6.45146
# [150]	validation-rmse:6.45113
# [151]	validation-rmse:6.45076
# [152]	validation-rmse:6.45012
# [153]	validation-rmse:6.44965
# [154]	validation-rmse:6.44905
# [155]	validation-rmse:6.44872
# [156]	validation-rmse:6.44825
# [157]	validation-rmse:6.44792
# [158]	validation-rmse:6.44743
# [159]	validation-rmse:6.44671
# [160]	validation-rmse:6.44616
# [161]	validation-rmse:6.44562
# [162]	validation-rmse:6.44503
# [163]	validation-rmse:6.44434
# [164]	validation-rmse:6.44399
# [165]	validation-rmse:6.44339
# [166]	validation-rmse:6.44303
# [167]	validation-rmse:6.44260
# [168]	validation-rmse:6.44207
# [169]	validation-rmse:6.44173
# [170]	validation-rmse:6.44107
# [171]	validation-rmse:6.44068
# [172]	validation-rmse:6.44007
# [173]	validation-rmse:6.43964
# [174]	validation-rmse:6.43918
# [175]	validation-rmse:6.43883
# [176]	validation-rmse:6.43842
# [177]	validation-rmse:6.43803
# [178]	validation-rmse:6.43759
# [179]	validation-rmse:6.43714
# [180]	validation-rmse:6.43676
# [181]	validation-rmse:6.43644
# [182]	validation-rmse:6.43605
# [183]	validation-rmse:6.43571
# [184]	validation-rmse:6.43527
# [185]	validation-rmse:6.43489
# [186]	validation-rmse:6.43435
# [187]	validation-rmse:6.43408
# [188]	validation-rmse:6.43376
# [189]	validation-rmse:6.43360
# [190]	validation-rmse:6.43347
# [191]	validation-rmse:6.43343
# [192]	validation-rmse:6.43284
# [193]	validation-rmse:6.43259
# [194]	validation-rmse:6.43222
# [195]	validation-rmse:6.43187
# [196]	validation-rmse:6.43157
# [197]	validation-rmse:6.43102
# [198]	validation-rmse:6.43084
# [199]	validation-rmse:6.43085
# [200]	validation-rmse:6.43072
# [201]	validation-rmse:6.43048
# [202]	validation-rmse:6.43004
# [203]	validation-rmse:6.42961
# [204]	validation-rmse:6.42896
# [205]	validation-rmse:6.42861
# [206]	validation-rmse:6.42831
# [207]	validation-rmse:6.42808
# [208]	validation-rmse:6.42801
# [209]	validation-rmse:6.42755
# [210]	validation-rmse:6.42700
# [211]	validation-rmse:6.42653
# [212]	validation-rmse:6.42617
# [213]	validation-rmse:6.42564
# [214]	validation-rmse:6.42532
# [215]	validation-rmse:6.42478
# [216]	validation-rmse:6.42448
# [217]	validation-rmse:6.42402
# [218]	validation-rmse:6.42359
# [219]	validation-rmse:6.42338
# [220]	validation-rmse:6.42298
# [221]	validation-rmse:6.42271
# [222]	validation-rmse:6.42247
# [223]	validation-rmse:6.42197
# [224]	validation-rmse:6.42171
# [225]	validation-rmse:6.42122
# [226]	validation-rmse:6.42061
# [227]	validation-rmse:6.42051
# [228]	validation-rmse:6.42004
# [229]	validation-rmse:6.41970
# [230]	validation-rmse:6.41931
# [231]	validation-rmse:6.41891
# [232]	validation-rmse:6.41880
# [233]	validation-rmse:6.41871
# [234]	validation-rmse:6.41846
# [235]	validation-rmse:6.41782
# [236]	validation-rmse:6.41750
# [237]	validation-rmse:6.41718
# [238]	validation-rmse:6.41680
# [239]	validation-rmse:6.41642
# [240]	validation-rmse:6.41611
# [241]	validation-rmse:6.41599
# [242]	validation-rmse:6.41567
# [243]	validation-rmse:6.41528
# [244]	validation-rmse:6.41504
# [245]	validation-rmse:6.41465
# [246]	validation-rmse:6.41431
# [247]	validation-rmse:6.41400
# [248]	validation-rmse:6.41364
# [249]	validation-rmse:6.41342
# [250]	validation-rmse:6.41328
# [251]	validation-rmse:6.41325
# [252]	validation-rmse:6.41308
# [253]	validation-rmse:6.41279
# [254]	validation-rmse:6.41259
# [255]	validation-rmse:6.41198
# [256]	validation-rmse:6.41179
# [257]	validation-rmse:6.41155
# [258]	validation-rmse:6.41131
# [259]	validation-rmse:6.41075
# [260]	validation-rmse:6.41055
# [261]	validation-rmse:6.41016
# [262]	validation-rmse:6.41002
# [263]	validation-rmse:6.41006
# [264]	validation-rmse:6.40985
# [265]	validation-rmse:6.40970
# [266]	validation-rmse:6.40951
# [267]	validation-rmse:6.40926
# [268]	validation-rmse:6.40903
# [269]	validation-rmse:6.40865
# [270]	validation-rmse:6.40830
# [271]	validation-rmse:6.40805
# [272]	validation-rmse:6.40790
# [273]	validation-rmse:6.40767
# [274]	validation-rmse:6.40749
# [275]	validation-rmse:6.40734
# [276]	validation-rmse:6.40696
# [277]	validation-rmse:6.40666
# [278]	validation-rmse:6.40632
# [279]	validation-rmse:6.40581
# [280]	validation-rmse:6.40552
# [281]	validation-rmse:6.40505
# [282]	validation-rmse:6.40472
# [283]	validation-rmse:6.40449
# [284]	validation-rmse:6.40420
# [285]	validation-rmse:6.40377
# [286]	validation-rmse:6.40347
# [287]	validation-rmse:6.40305
# [288]	validation-rmse:6.40283
# [289]	validation-rmse:6.40268
# [290]	validation-rmse:6.40245
# [291]	validation-rmse:6.40219
# [292]	validation-rmse:6.40207
# [293]	validation-rmse:6.40178
# [294]	validation-rmse:6.40135
# [295]	validation-rmse:6.40101
# [296]	validation-rmse:6.40064
# [297]	validation-rmse:6.40041
# [298]	validation-rmse:6.40004
# [299]	validation-rmse:6.39995
# [300]	validation-rmse:6.39958
# [301]	validation-rmse:6.39939
# [302]	validation-rmse:6.39900
# [303]	validation-rmse:6.39883
# [304]	validation-rmse:6.39869
# [305]	validation-rmse:6.39846
# [306]	validation-rmse:6.39837
# [307]	validation-rmse:6.39819
# [308]	validation-rmse:6.39793
# [309]	validation-rmse:6.39771
# [310]	validation-rmse:6.39720
# [311]	validation-rmse:6.39687
# [312]	validation-rmse:6.39660
# [313]	validation-rmse:6.39603
# [314]	validation-rmse:6.39590
# [315]	validation-rmse:6.39579
# [316]	validation-rmse:6.39557
# [317]	validation-rmse:6.39519
# [318]	validation-rmse:6.39501
# [319]	validation-rmse:6.39472
# [320]	validation-rmse:6.39456
# [321]	validation-rmse:6.39437
# [322]	validation-rmse:6.39419
# [323]	validation-rmse:6.39385
# [324]	validation-rmse:6.39350
# [325]	validation-rmse:6.39331
# [326]	validation-rmse:6.39326
# [327]	validation-rmse:6.39311
# [328]	validation-rmse:6.39315
# [329]	validation-rmse:6.39302
# [330]	validation-rmse:6.39281
# [331]	validation-rmse:6.39274
# [332]	validation-rmse:6.39254
# [333]	validation-rmse:6.39242
# [334]	validation-rmse:6.39193
# [335]	validation-rmse:6.39169
# [336]	validation-rmse:6.39148
# [337]	validation-rmse:6.39136
# [338]	validation-rmse:6.39108
# [339]	validation-rmse:6.39103
# [340]	validation-rmse:6.39079
# [341]	validation-rmse:6.39058
# [342]	validation-rmse:6.39045
# [343]	validation-rmse:6.39022
# [344]	validation-rmse:6.39024
# [345]	validation-rmse:6.39007
# [346]	validation-rmse:6.39002
# [347]	validation-rmse:6.38999
# [348]	validation-rmse:6.38977
# [349]	validation-rmse:6.38951
# [350]	validation-rmse:6.38951
# [351]	validation-rmse:6.38944
# [352]	validation-rmse:6.38923
# [353]	validation-rmse:6.38903
# [354]	validation-rmse:6.38885
# [355]	validation-rmse:6.38867
# [356]	validation-rmse:6.38856
# [357]	validation-rmse:6.38845
# [358]	validation-rmse:6.38818
# [359]	validation-rmse:6.38787
# [360]	validation-rmse:6.38751
# [361]	validation-rmse:6.38704
# [362]	validation-rmse:6.38673
# [363]	validation-rmse:6.38648
# [364]	validation-rmse:6.38626
# [365]	validation-rmse:6.38610
# [366]	validation-rmse:6.38573
# [367]	validation-rmse:6.38525
# [368]	validation-rmse:6.38505
# [369]	validation-rmse:6.38483
# [370]	validation-rmse:6.38457
# [371]	validation-rmse:6.38450
# [372]	validation-rmse:6.38420
# [373]	validation-rmse:6.38398
# [374]	validation-rmse:6.38392
# [375]	validation-rmse:6.38368
# [376]	validation-rmse:6.38342
# [377]	validation-rmse:6.38321
# [378]	validation-rmse:6.38318
# [379]	validation-rmse:6.38285
# [380]	validation-rmse:6.38258
# [381]	validation-rmse:6.38225
# [382]	validation-rmse:6.38211
# [383]	validation-rmse:6.38171
# [384]	validation-rmse:6.38155
# [385]	validation-rmse:6.38138
# [386]	validation-rmse:6.38110
# [387]	validation-rmse:6.38089
# [388]	validation-rmse:6.38071
# [389]	validation-rmse:6.38059
# [390]	validation-rmse:6.38023
# [391]	validation-rmse:6.38004
# [392]	validation-rmse:6.37982
# [393]	validation-rmse:6.37962
# [394]	validation-rmse:6.37968
# [395]	validation-rmse:6.37956
# [396]	validation-rmse:6.37937
# [397]	validation-rmse:6.37885
# [398]	validation-rmse:6.37864
# [399]	validation-rmse:6.37815
# [400]	validation-rmse:6.37803
# [401]	validation-rmse:6.37778
# [402]	validation-rmse:6.37749
# [403]	validation-rmse:6.37731
# [404]	validation-rmse:6.37712
# [405]	validation-rmse:6.37698
# [406]	validation-rmse:6.37677
# [407]	validation-rmse:6.37658
# [408]	validation-rmse:6.37647
# [409]	validation-rmse:6.37631
# [410]	validation-rmse:6.37617
# [411]	validation-rmse:6.37575
# [412]	validation-rmse:6.37566
# [413]	validation-rmse:6.37556
# [414]	validation-rmse:6.37533
# [415]	validation-rmse:6.37538
# [416]	validation-rmse:6.37541
# [417]	validation-rmse:6.37530
# [418]	validation-rmse:6.37511
# [419]	validation-rmse:6.37512
# [420]	validation-rmse:6.37496
# [421]	validation-rmse:6.37483
# [422]	validation-rmse:6.37478
# [423]	validation-rmse:6.37466
# [424]	validation-rmse:6.37440
# [425]	validation-rmse:6.37416
# [426]	validation-rmse:6.37387
# [427]	validation-rmse:6.37384
# [428]	validation-rmse:6.37367
# [429]	validation-rmse:6.37357
# [430]	validation-rmse:6.37345
# [431]	validation-rmse:6.37330
# [432]	validation-rmse:6.37293
# [433]	validation-rmse:6.37265
# [434]	validation-rmse:6.37245
# [435]	validation-rmse:6.37236
# [436]	validation-rmse:6.37233
# [437]	validation-rmse:6.37222
# [438]	validation-rmse:6.37221
# [439]	validation-rmse:6.37218
# [440]	validation-rmse:6.37198
# [441]	validation-rmse:6.37195
# [442]	validation-rmse:6.37190
# [443]	validation-rmse:6.37189
# [444]	validation-rmse:6.37171
# [445]	validation-rmse:6.37159
# [446]	validation-rmse:6.37148
# [447]	validation-rmse:6.37152
# [448]	validation-rmse:6.37128
# [449]	validation-rmse:6.37125
# [450]	validation-rmse:6.37110
# [451]	validation-rmse:6.37086
# [452]	validation-rmse:6.37067
# [453]	validation-rmse:6.37035
# [454]	validation-rmse:6.37019
# [455]	validation-rmse:6.36995
# [456]	validation-rmse:6.36964
# [457]	validation-rmse:6.36935
# [458]	validation-rmse:6.36895
# [459]	validation-rmse:6.36883
# [460]	validation-rmse:6.36862
# [461]	validation-rmse:6.36842
# [462]	validation-rmse:6.36826
# [463]	validation-rmse:6.36789
# [464]	validation-rmse:6.36769
# [465]	validation-rmse:6.36769
# [466]	validation-rmse:6.36764
# [467]	validation-rmse:6.36735
# [468]	validation-rmse:6.36717
# [469]	validation-rmse:6.36706
# [470]	validation-rmse:6.36690
# [471]	validation-rmse:6.36676
# [472]	validation-rmse:6.36671
# [473]	validation-rmse:6.36656
# [474]	validation-rmse:6.36627
# [475]	validation-rmse:6.36626
# [476]	validation-rmse:6.36614
# [477]	validation-rmse:6.36595
# [478]	validation-rmse:6.36597
# [479]	validation-rmse:6.36584
# [480]	validation-rmse:6.36566
# [481]	validation-rmse:6.36531
# [482]	validation-rmse:6.36523
# [483]	validation-rmse:6.36517
# [484]	validation-rmse:6.36487
# [485]	validation-rmse:6.36472
# [486]	validation-rmse:6.36459
# [487]	validation-rmse:6.36439
# [488]	validation-rmse:6.36424
# [489]	validation-rmse:6.36401
# [490]	validation-rmse:6.36386
# [491]	validation-rmse:6.36369
# [492]	validation-rmse:6.36348
# [493]	validation-rmse:6.36316
# [494]	validation-rmse:6.36311
# [495]	validation-rmse:6.36313
# [496]	validation-rmse:6.36295
# [497]	validation-rmse:6.36292
# [498]	validation-rmse:6.36283
# [499]	validation-rmse:6.36268
# [500]	validation-rmse:6.36237
# [501]	validation-rmse:6.36220
# [502]	validation-rmse:6.36207
# [503]	validation-rmse:6.36177
# [504]	validation-rmse:6.36172
# [505]	validation-rmse:6.36153
# [506]	validation-rmse:6.36143
# [507]	validation-rmse:6.36129
# [508]	validation-rmse:6.36116
# [509]	validation-rmse:6.36092
# [510]	validation-rmse:6.36073
# [511]	validation-rmse:6.36044
# [512]	validation-rmse:6.36036
# [513]	validation-rmse:6.36024
# [514]	validation-rmse:6.36008
# [515]	validation-rmse:6.36008
# [516]	validation-rmse:6.35995
# [517]	validation-rmse:6.36001
# [518]	validation-rmse:6.35985
# [519]	validation-rmse:6.35968
# [520]	validation-rmse:6.35961
# [521]	validation-rmse:6.35962
# [522]	validation-rmse:6.35963
# [523]	validation-rmse:6.35945
# [524]	validation-rmse:6.35932
# [525]	validation-rmse:6.35923
# [526]	validation-rmse:6.35909
# [527]	validation-rmse:6.35908
# [528]	validation-rmse:6.35911
# [529]	validation-rmse:6.35892
# [530]	validation-rmse:6.35873
# [531]	validation-rmse:6.35860
# [532]	validation-rmse:6.35828
# [533]	validation-rmse:6.35824
# [534]	validation-rmse:6.35805
# [535]	validation-rmse:6.35791
# [536]	validation-rmse:6.35774
# [537]	validation-rmse:6.35752
# [538]	validation-rmse:6.35727
# [539]	validation-rmse:6.35711
# [540]	validation-rmse:6.35700
# [541]	validation-rmse:6.35692
# [542]	validation-rmse:6.35679
# [543]	validation-rmse:6.35677
# [544]	validation-rmse:6.35678
# [545]	validation-rmse:6.35676
# [546]	validation-rmse:6.35671
# [547]	validation-rmse:6.35666
# [548]	validation-rmse:6.35675
# [549]	validation-rmse:6.35666
# [550]	validation-rmse:6.35656
# [551]	validation-rmse:6.35636
# [552]	validation-rmse:6.35630
# [553]	validation-rmse:6.35613
# [554]	validation-rmse:6.35621
# [555]	validation-rmse:6.35604
# [556]	validation-rmse:6.35586
# [557]	validation-rmse:6.35563
# [558]	validation-rmse:6.35564
# [559]	validation-rmse:6.35548
# [560]	validation-rmse:6.35528
# [561]	validation-rmse:6.35488
# [562]	validation-rmse:6.35475
# [563]	validation-rmse:6.35457
# [564]	validation-rmse:6.35443
# [565]	validation-rmse:6.35436
# [566]	validation-rmse:6.35431
# [567]	validation-rmse:6.35407
# [568]	validation-rmse:6.35379
# [569]	validation-rmse:6.35378
# [570]	validation-rmse:6.35371
# [571]	validation-rmse:6.35347
# [572]	validation-rmse:6.35313
# [573]	validation-rmse:6.35301
# [574]	validation-rmse:6.35292
# [575]	validation-rmse:6.35259
# [576]	validation-rmse:6.35244
# [577]	validation-rmse:6.35232
# [578]	validation-rmse:6.35216
# [579]	validation-rmse:6.35197
# [580]	validation-rmse:6.35184
# [581]	validation-rmse:6.35171
# [582]	validation-rmse:6.35158
# [583]	validation-rmse:6.35155
# [584]	validation-rmse:6.35141
# [585]	validation-rmse:6.35150
# [586]	validation-rmse:6.35138
# [587]	validation-rmse:6.35135
# [588]	validation-rmse:6.35117
# [589]	validation-rmse:6.35092
# [590]	validation-rmse:6.35080
# [591]	validation-rmse:6.35072
# [592]	validation-rmse:6.35060
# [593]	validation-rmse:6.35054
# [594]	validation-rmse:6.35044
# [595]	validation-rmse:6.35023
# [596]	validation-rmse:6.35024
# [597]	validation-rmse:6.35010
# [598]	validation-rmse:6.34977
# [599]	validation-rmse:6.34970
# [600]	validation-rmse:6.34944
# [601]	validation-rmse:6.34945
# [602]	validation-rmse:6.34938
# [603]	validation-rmse:6.34915
# [604]	validation-rmse:6.34891
# [605]	validation-rmse:6.34870
# [606]	validation-rmse:6.34850
# [607]	validation-rmse:6.34852
# [608]	validation-rmse:6.34834
# [609]	validation-rmse:6.34821
# [610]	validation-rmse:6.34807
# [611]	validation-rmse:6.34796
# [612]	validation-rmse:6.34790
# [613]	validation-rmse:6.34777
# [614]	validation-rmse:6.34769
# [615]	validation-rmse:6.34750
# [616]	validation-rmse:6.34707
# [617]	validation-rmse:6.34703
# [618]	validation-rmse:6.34698
# [619]	validation-rmse:6.34688
# [620]	validation-rmse:6.34668
# [621]	validation-rmse:6.34654
# [622]	validation-rmse:6.34654
# [623]	validation-rmse:6.34648
# [624]	validation-rmse:6.34656
# [625]	validation-rmse:6.34648
# [626]	validation-rmse:6.34634
# [627]	validation-rmse:6.34633
# [628]	validation-rmse:6.34629
# [629]	validation-rmse:6.34613
# [630]	validation-rmse:6.34611
# [631]	validation-rmse:6.34605
# [632]	validation-rmse:6.34591
# [633]	validation-rmse:6.34579
# [634]	validation-rmse:6.34573
# [635]	validation-rmse:6.34559
# [636]	validation-rmse:6.34558
# [637]	validation-rmse:6.34557
# [638]	validation-rmse:6.34547
# [639]	validation-rmse:6.34545
# [640]	validation-rmse:6.34505
# [641]	validation-rmse:6.34506
# [642]	validation-rmse:6.34503
# [643]	validation-rmse:6.34500
# [644]	validation-rmse:6.34477
# [645]	validation-rmse:6.34472
# [646]	validation-rmse:6.34472
# [647]	validation-rmse:6.34473
# [648]	validation-rmse:6.34462
# [649]	validation-rmse:6.34442
# [650]	validation-rmse:6.34423
# [651]	validation-rmse:6.34426
# [652]	validation-rmse:6.34401
# [653]	validation-rmse:6.34393
# [654]	validation-rmse:6.34376
# [655]	validation-rmse:6.34378
# [656]	validation-rmse:6.34363
# [657]	validation-rmse:6.34356
# [658]	validation-rmse:6.34328
# [659]	validation-rmse:6.34325
# [660]	validation-rmse:6.34311
# [661]	validation-rmse:6.34303
# [662]	validation-rmse:6.34303
# [663]	validation-rmse:6.34293
# [664]	validation-rmse:6.34310
# [665]	validation-rmse:6.34289
# [666]	validation-rmse:6.34279
# [667]	validation-rmse:6.34269
# [668]	validation-rmse:6.34260
# [669]	validation-rmse:6.34238
# [670]	validation-rmse:6.34223
# [671]	validation-rmse:6.34210
# [672]	validation-rmse:6.34207
# [673]	validation-rmse:6.34201
# [674]	validation-rmse:6.34192
# [675]	validation-rmse:6.34207
# [676]	validation-rmse:6.34191
# [677]	validation-rmse:6.34197
# [678]	validation-rmse:6.34185
# [679]	validation-rmse:6.34168
# [680]	validation-rmse:6.34158
# [681]	validation-rmse:6.34146
# [682]	validation-rmse:6.34140
# [683]	validation-rmse:6.34138
# [684]	validation-rmse:6.34125
# [685]	validation-rmse:6.34119
# [686]	validation-rmse:6.34118
# [687]	validation-rmse:6.34103
# [688]	validation-rmse:6.34101
# [689]	validation-rmse:6.34087
# [690]	validation-rmse:6.34075
# [691]	validation-rmse:6.34056
# [692]	validation-rmse:6.34040
# [693]	validation-rmse:6.34015
# [694]	validation-rmse:6.34005
# [695]	validation-rmse:6.33987
# [696]	validation-rmse:6.33983
# [697]	validation-rmse:6.33979
# [698]	validation-rmse:6.33971
# [699]	validation-rmse:6.33974
# [700]	validation-rmse:6.33952
# [701]	validation-rmse:6.33946
# [702]	validation-rmse:6.33958
# [703]	validation-rmse:6.33951
# [704]	validation-rmse:6.33946
# [705]	validation-rmse:6.33930
# [706]	validation-rmse:6.33904
# [707]	validation-rmse:6.33908
# [708]	validation-rmse:6.33892
# [709]	validation-rmse:6.33888
# [710]	validation-rmse:6.33870
# [711]	validation-rmse:6.33861
# [712]	validation-rmse:6.33847
# [713]	validation-rmse:6.33842
# [714]	validation-rmse:6.33833
# [715]	validation-rmse:6.33822
# [716]	validation-rmse:6.33830
# [717]	validation-rmse:6.33819
# [718]	validation-rmse:6.33814
# [719]	validation-rmse:6.33802
# [720]	validation-rmse:6.33802
# [721]	validation-rmse:6.33787
# [722]	validation-rmse:6.33773
# [723]	validation-rmse:6.33754
# [724]	validation-rmse:6.33732
# [725]	validation-rmse:6.33714
# [726]	validation-rmse:6.33689
# [727]	validation-rmse:6.33675
# [728]	validation-rmse:6.33656
# [729]	validation-rmse:6.33647
# [730]	validation-rmse:6.33638
# [731]	validation-rmse:6.33636
# [732]	validation-rmse:6.33618
# [733]	validation-rmse:6.33607
# [734]	validation-rmse:6.33600
# [735]	validation-rmse:6.33595
# [736]	validation-rmse:6.33595
# [737]	validation-rmse:6.33591
# [738]	validation-rmse:6.33585
# [739]	validation-rmse:6.33559
# [740]	validation-rmse:6.33557
# [741]	validation-rmse:6.33540
# [742]	validation-rmse:6.33534
# [743]	validation-rmse:6.33540
# [744]	validation-rmse:6.33526
# [745]	validation-rmse:6.33518
# [746]	validation-rmse:6.33513
# [747]	validation-rmse:6.33514
# [748]	validation-rmse:6.33508
# [749]	validation-rmse:6.33499
# [750]	validation-rmse:6.33497
# [751]	validation-rmse:6.33474
# [752]	validation-rmse:6.33480
# [753]	validation-rmse:6.33486
# [754]	validation-rmse:6.33465
# [755]	validation-rmse:6.33461
# [756]	validation-rmse:6.33457
# [757]	validation-rmse:6.33448
# [758]	validation-rmse:6.33445
# [759]	validation-rmse:6.33440
# [760]	validation-rmse:6.33427
# [761]	validation-rmse:6.33406
# [762]	validation-rmse:6.33400
# [763]	validation-rmse:6.33401
# [764]	validation-rmse:6.33395
# [765]	validation-rmse:6.33388
# [766]	validation-rmse:6.33372
# [767]	validation-rmse:6.33379
# [768]	validation-rmse:6.33383
# [769]	validation-rmse:6.33372
# [770]	validation-rmse:6.33365
# [771]	validation-rmse:6.33366
# [772]	validation-rmse:6.33365
# [773]	validation-rmse:6.33364
# [774]	validation-rmse:6.33363
# [775]	validation-rmse:6.33350
# [776]	validation-rmse:6.33317
# [777]	validation-rmse:6.33316
# [778]	validation-rmse:6.33307
# [779]	validation-rmse:6.33306
# [780]	validation-rmse:6.33279
# [781]	validation-rmse:6.33267
# [782]	validation-rmse:6.33249
# [783]	validation-rmse:6.33235
# [784]	validation-rmse:6.33204
# [785]	validation-rmse:6.33197
# [786]	validation-rmse:6.33194
# [787]	validation-rmse:6.33177
# [788]	validation-rmse:6.33186
# [789]	validation-rmse:6.33172
# [790]	validation-rmse:6.33167
# [791]	validation-rmse:6.33159
# [792]	validation-rmse:6.33160
# [793]	validation-rmse:6.33168
# [794]	validation-rmse:6.33172
# [795]	validation-rmse:6.33154
# [796]	validation-rmse:6.33146
# [797]	validation-rmse:6.33128
# [798]	validation-rmse:6.33118
# [799]	validation-rmse:6.33111
# [800]	validation-rmse:6.33117
# [801]	validation-rmse:6.33116
# [802]	validation-rmse:6.33095
# [803]	validation-rmse:6.33097
# [804]	validation-rmse:6.33101
# [805]	validation-rmse:6.33097
# [806]	validation-rmse:6.33088
# [807]	validation-rmse:6.33089
# [808]	validation-rmse:6.33091
# [809]	validation-rmse:6.33092
# [810]	validation-rmse:6.33079
# [811]	validation-rmse:6.33072
# [812]	validation-rmse:6.33076
# [813]	validation-rmse:6.33066
# [814]	validation-rmse:6.33062
# [815]	validation-rmse:6.33050
# [816]	validation-rmse:6.33026
# [817]	validation-rmse:6.33024
# [818]	validation-rmse:6.33027
# [819]	validation-rmse:6.33023
# [820]	validation-rmse:6.33019
# [821]	validation-rmse:6.33007
# [822]	validation-rmse:6.32995
# [823]	validation-rmse:6.32997
# [824]	validation-rmse:6.32989
# [825]	validation-rmse:6.32990
# [826]	validation-rmse:6.32972
# [827]	validation-rmse:6.32970
# [828]	validation-rmse:6.32958
# [829]	validation-rmse:6.32960
# [830]	validation-rmse:6.32935
# [831]	validation-rmse:6.32935
# [832]	validation-rmse:6.32924
# [833]	validation-rmse:6.32914
# [834]	validation-rmse:6.32909
# [835]	validation-rmse:6.32881
# [836]	validation-rmse:6.32883
# [837]	validation-rmse:6.32881
# [838]	validation-rmse:6.32873
# [839]	validation-rmse:6.32861
# [840]	validation-rmse:6.32864
# [841]	validation-rmse:6.32855
# [842]	validation-rmse:6.32851
# [843]	validation-rmse:6.32846
# [844]	validation-rmse:6.32829
# [845]	validation-rmse:6.32817
# [846]	validation-rmse:6.32795
# [847]	validation-rmse:6.32786
# [848]	validation-rmse:6.32772
# [849]	validation-rmse:6.32758
# [850]	validation-rmse:6.32751
# [851]	validation-rmse:6.32749
# [852]	validation-rmse:6.32739
# [853]	validation-rmse:6.32729
# [854]	validation-rmse:6.32725
# [855]	validation-rmse:6.32729
# [856]	validation-rmse:6.32718
# [857]	validation-rmse:6.32688
# [858]	validation-rmse:6.32680
# [859]	validation-rmse:6.32676
# [860]	validation-rmse:6.32663
# [861]	validation-rmse:6.32637
# [862]	validation-rmse:6.32633
# [863]	validation-rmse:6.32626
# [864]	validation-rmse:6.32634
# [865]	validation-rmse:6.32645
# [866]	validation-rmse:6.32627
# [867]	validation-rmse:6.32618
# [868]	validation-rmse:6.32603
# [869]	validation-rmse:6.32574
# [870]	validation-rmse:6.32571
# [871]	validation-rmse:6.32574
# [872]	validation-rmse:6.32589
# [873]	validation-rmse:6.32584
# [874]	validation-rmse:6.32579
# [875]	validation-rmse:6.32573
# [876]	validation-rmse:6.32547
# [877]	validation-rmse:6.32546
# [878]	validation-rmse:6.32552
# [879]	validation-rmse:6.32545
# [880]	validation-rmse:6.32552
# [881]	validation-rmse:6.32532
# [882]	validation-rmse:6.32527
# [883]	validation-rmse:6.32525
# [884]	validation-rmse:6.32520
# [885]	validation-rmse:6.32506
# [886]	validation-rmse:6.32466
# [887]	validation-rmse:6.32466
# [888]	validation-rmse:6.32470
# [889]	validation-rmse:6.32461
# [890]	validation-rmse:6.32450
# [891]	validation-rmse:6.32444
# [892]	validation-rmse:6.32432
# [893]	validation-rmse:6.32420
# [894]	validation-rmse:6.32408
# [895]	validation-rmse:6.32403
# [896]	validation-rmse:6.32392
# [897]	validation-rmse:6.32379
# [898]	validation-rmse:6.32383
# [899]	validation-rmse:6.32379
# [900]	validation-rmse:6.32371
# [901]	validation-rmse:6.32332
# [902]	validation-rmse:6.32334
# [903]	validation-rmse:6.32343
# [904]	validation-rmse:6.32333
# [905]	validation-rmse:6.32333
# [906]	validation-rmse:6.32335
# [907]	validation-rmse:6.32332
# [908]	validation-rmse:6.32329
# [909]	validation-rmse:6.32330
# [910]	validation-rmse:6.32319
# [911]	validation-rmse:6.32313
# [912]	validation-rmse:6.32315
# [913]	validation-rmse:6.32306
# [914]	validation-rmse:6.32299
# [915]	validation-rmse:6.32289
# [916]	validation-rmse:6.32287
# [917]	validation-rmse:6.32273
# [918]	validation-rmse:6.32267
# [919]	validation-rmse:6.32259
# [920]	validation-rmse:6.32237
# [921]	validation-rmse:6.32216
# [922]	validation-rmse:6.32213
# [923]	validation-rmse:6.32221
# [924]	validation-rmse:6.32206
# [925]	validation-rmse:6.32204
# [926]	validation-rmse:6.32193
# [927]	validation-rmse:6.32191
# [928]	validation-rmse:6.32170
# [929]	validation-rmse:6.32149
# [930]	validation-rmse:6.32156
# [931]	validation-rmse:6.32149
# [932]	validation-rmse:6.32146
# [933]	validation-rmse:6.32152
# [934]	validation-rmse:6.32135
# [935]	validation-rmse:6.32131
# [936]	validation-rmse:6.32133
# [937]	validation-rmse:6.32130
# [938]	validation-rmse:6.32129
# [939]	validation-rmse:6.32120
# [940]	validation-rmse:6.32104
# [941]	validation-rmse:6.32097
# [942]	validation-rmse:6.32088
# [943]	validation-rmse:6.32082
# [944]	validation-rmse:6.32089
# [945]	validation-rmse:6.32102
# [946]	validation-rmse:6.32074
# [947]	validation-rmse:6.32082
# [948]	validation-rmse:6.32074
# [949]	validation-rmse:6.32066
# [950]	validation-rmse:6.32043
# [951]	validation-rmse:6.32020
# [952]	validation-rmse:6.32007
# [953]	validation-rmse:6.32009
# [954]	validation-rmse:6.32009
# [955]	validation-rmse:6.32004
# [956]	validation-rmse:6.32001
# [957]	validation-rmse:6.31998
# [958]	validation-rmse:6.31987
# [959]	validation-rmse:6.31992
# [960]	validation-rmse:6.31981
# [961]	validation-rmse:6.31981
# [962]	validation-rmse:6.31983
# [963]	validation-rmse:6.31978
# [964]	validation-rmse:6.31960
# [965]	validation-rmse:6.31961
# [966]	validation-rmse:6.31958
# [967]	validation-rmse:6.31948
# [968]	validation-rmse:6.31946
# [969]	validation-rmse:6.31950
# [970]	validation-rmse:6.31951
# [971]	validation-rmse:6.31957
# [972]	validation-rmse:6.31957
# [973]	validation-rmse:6.31959
# [974]	validation-rmse:6.31942
# [975]	validation-rmse:6.31937
# [976]	validation-rmse:6.31937
# [977]	validation-rmse:6.31927
# [978]	validation-rmse:6.31919
# [979]	validation-rmse:6.31919
# [980]	validation-rmse:6.31907
# [981]	validation-rmse:6.31907
# [982]	validation-rmse:6.31898
# [983]	validation-rmse:6.31904
# [984]	validation-rmse:6.31907
# [985]	validation-rmse:6.31894
# [986]	validation-rmse:6.31894
# [987]	validation-rmse:6.31893
# [988]	validation-rmse:6.31877
# [989]	validation-rmse:6.31896
# [990]	validation-rmse:6.31893
# [991]	validation-rmse:6.31875
# [992]	validation-rmse:6.31862
# [993]	validation-rmse:6.31853
# [994]	validation-rmse:6.31855
# [995]	validation-rmse:6.31848
# [996]	validation-rmse:6.31855
# [997]	validation-rmse:6.31850
# [998]	validation-rmse:6.31857
# [999]	validation-rmse:6.31845
# /usr/local/anaconda3/lib/python3.12/site-packages/mlflow/xgboost/__init__.py:168: UserWarning: [12:25:54] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1427: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   xgb_model.save_model(model_data_path)
# 2025/05/08 12:26:01 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %% [markdown]
# # 4.0 Loading a model

# %%
# we pass the run id
logged_model = "runs:/0eeed647ce134080b75df6742764b655/models_mlflow"

# load model as a PyFuncModel
loaded_model = mlflow.pyfunc.load_model(logged_model)

# predict on pandas DataFrame
import pandas as pd
#loaded_model.predict(pd.DataFrame({'', 'trip_distance': [1.0]}))  # you need to pass the data in the same format as the model was trained

# %%
#check the loaded model
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: 0eeed647ce134080b75df6742764b655

# %% [markdown]
# You can also load the model as a xgboost model (in this case)

# %%
xgboost_model = mlflow.xgboost.load_model(logged_model)

# %%
# check the xgboost object
xgboost_model

# %% [markdown]
# # 5.0 Search with a lot of models

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)
